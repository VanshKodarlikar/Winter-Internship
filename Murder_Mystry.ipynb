# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshKodarlikar/Winter-Internship/blob/main/Murder_Mystry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('/content/sql-murder-mystery.db')  #/content/sql_murder_mystery.sql

# %%
print(conn)

# %%
df = '''
SELECT *
FROM crime_scene_report
WHERE city = "SQL City"
ORDER BY date;
'''
pd.set_option('display.max_colwidth', None)
pd.read_sql_query(df, conn)
# Out:
#        date     type  \
# 0  20170712    theft
# 1  20170820    arson
# 2  20171110  robbery
# 3  20180103  bribery
# 4  20180115  assault
# 5  20180115  assault
# 6  20180115   murder
# 7  20180215   murder
# 8  20180215   murder
#
#                                                                                                                                                                                                                                                               description  \
# 0              A lone hunter stalks the night, firing arrows into the Darkness.\n            There is no hiding, no escape. In the distance, the beast\n            falters, tethered to the void. The killing blow comes without\n            hesitation, without mercy.
# ...

# %%
query_2 = '''
SELECT *
FROM Person
WHERE address_street_name ='Northwestern Dr'
ORDER BY address_number desc;
'''

# %%
pd.read_sql_query(query_2, conn)[:1]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
query_3 = '''
SELECT *
FROM Person
WHERE address_street_name ='Franklin Ave'
ORDER BY address_number desc;
'''

# %%
pd.read_sql_query(query_3, conn)[:5]
# Out:
#       id               name  license_id  address_number address_street_name  \
# 0  24737         Gema Nantz      273410            3968        Franklin Ave
# 1  84531     Edgar Mendieta      315790            3881        Franklin Ave
# 2  36328       Domenic Laun      971080            3809        Franklin Ave
# 3  34592  Cordell Lindamood      592762            3657        Franklin Ave
# 4  83003     Wilmer Casella      672050            3564        Franklin Ave
#
#          ssn
# 0  180545802
# 1  458847132
# 2  825329637
# 3  509890333
# 4  569057540

# %%
df1= '''
SELECT * FROM crime_scene_report WHERE date = '20180115' and type ='murder' and city ='SQL City'
'''
pd.read_sql_query(df1, conn)
# Out:
#        date    type  \
# 0  20180115  murder
#
#                                                                                                                                                                                  description  \
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#        city
# 0  SQL City

# %%
df2='''
select * from person where address_street_name='Northwestern Dr'
'''
pd.read_sql_query(df2, conn)[:8]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  10010       Muoi Cary      385336             741     Northwestern Dr
# 1  12711  Norman Apolito      667757             599     Northwestern Dr
# 2  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 3  15171    Weldon Penso      336999             311     Northwestern Dr
# 4  17729  Lasonya Wildey      439686            3824     Northwestern Dr
# 5  18376        Josh Shi      653712            1091     Northwestern Dr
# 6  19420     Cody Schiel      890431            3524     Northwestern Dr
# 7  22239   Dusty Sigafus      710517            1125     Northwestern Dr
#
#          ssn
# 0  828638512
# 1  778264744
# 2  111564949
# 3  131379495
# 4  917817122
# 5  193899001
# 6  947110049
# 7  724386723

# %%
df3='''
select * from person where address_street_name='Northwestern Dr' order by address_number desc
'''
pd.read_sql_query(df3, conn)[:8]
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  14887       Morty Schapiro      118009            4919     Northwestern Dr
# 1  17729       Lasonya Wildey      439686            3824     Northwestern Dr
# 2  53890       Sophie Tiberio      957671            3755     Northwestern Dr
# 3  73368       Torie Thalmann      773862            3697     Northwestern Dr
# 4  96595        Coretta Cubie      303645            3631     Northwestern Dr
# 5  19420          Cody Schiel      890431            3524     Northwestern Dr
# 6  93509       Emmitt Aceuedo      916706            3491     Northwestern Dr
# 7  87456  Leonora Wolfsberger      215868            3483     Northwestern Dr
#
#          ssn
# 0  111564949
# 1  917817122
# 2  442830147
# 3  341559436
# 4  378403829
# 5  947110049
# 6  979073160
# 7  565203106

# %%
df4='''
select * from person where name like '%Annabel%'
'''
pd.read_sql_query(df4, conn)[:8]
# Out:
#       id                name  license_id  address_number address_street_name  \
# 0  16371      Annabel Miller      490173             103        Franklin Ave
# 1  78354      Annabell Siona      158932             978       Whitewater Dr
# 2  78799  Annabell Droneburg      984316            1944        W Natalie Dr
# 3  86541   Annabell Zwilling      709133            1859            Patti Rd
#
#          ssn
# 0  318771143
# 1  800278294
# 2  478793500
# 3  332961158

# %%
df5='''
select * from person where name like '%Annabel%' and address_street_name='Franklin Ave'
'''
pd.read_sql_query(df5, conn)[:8]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
df6='''
select * from interview where person_id in (14887,16371)
'''
pd.read_sql_query(df6, conn)
# Out:
#    person_id  \
# 0      14887
# 1      16371
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# 1                                                                                                            I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
df7='''
select * from get_fit_now_member where membership_status='gold'
'''
pd.read_sql_query(df7, conn)
# Out:
#        id  person_id               name  membership_start_date  \
# 0   NL318      65076    Everette Koepke               20170926
# 1   0YJ24      80651     Waneta Wellard               20171206
# 2   5Y28Y      15218  Millicent Yessios               20180205
# 3   A5N3S      24541       Mary Cameron               20170501
# 4   R4J4S      13703         Lien Yasin               20170414
# ..    ...        ...                ...                    ...
# 63  0T622      98782    Sarina Overpeck               20171109
# 64  BL3KC      24033      Collene Gulde               20170913
# 65  48Z7A      28819       Joe Germuska               20160305
# 66  48Z55      67318      Jeremy Bowers               20160101
# 67  90081      16371     Annabel Miller               20160208
#
#    membership_status
# 0               gold
# 1               gold
# 2               gold
# 3               gold
# 4               gold
# ..               ...
# 63              gold
# 64              gold
# ...

# %%
df8='''
select * from get_fit_now_member where membership_status='gold' and id like '%48Z%'
'''
pd.read_sql_query(df8, conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
df9='''
select * from drivers_license where plate_number like '%M42%'
'''
pd.read_sql_query(df9, conn)
# Out:
#        id  age  height eye_color hair_color gender plate_number car_make  \
# 0  477982   29      54     black      black   male       M42D25      BMW
#
#   car_model
# 0  3 Series

# %%
df10='''
select p.name,p.id,plate_number from person p
left join drivers_license d on d.id=p.license_id
where p.id in (67318,28819)
and d.plate_number like '%H42W%'
'''
pd.read_sql_query(df10, conn)
# Out:
#             name     id plate_number
# 0  Jeremy Bowers  67318       0H42W2

# %% [markdown]
# First Murderer : ***Jeremy Bowers***

# %%
new='''
select * from interview where person_id='	67318'
'''
pd.read_sql_query(new, conn)
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
new2='''
select p.id,p.name,d.hair_color,d.height,d.gender,i.annual_income,
d.car_make,d.car_model
from person p
left join drivers_license d on d.id=p.license_id
left join income i on i.ssn=p.ssn
left join facebook_event_checkin f on p.id=f.person_id
where d.hair_color='red' and height between 65 and 67
and d.gender='female' and d.car_make='Tesla' and car_model='Model S'
and f.event_name= 'SQL Symphony Concert' and date between '20171201' and '20171231'
order by i.annual_income desc
'''
pd.read_sql_query(new2, conn)
# Out:
#       id              name hair_color  height  gender  annual_income car_make  \
# 0  99716  Miranda Priestly        red      66  female         310000    Tesla
# 1  99716  Miranda Priestly        red      66  female         310000    Tesla
# 2  99716  Miranda Priestly        red      66  female         310000    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %% [markdown]
#  Second Murderer: ***Miranda Priestly***
